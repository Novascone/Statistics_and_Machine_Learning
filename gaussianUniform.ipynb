# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns 
sns.set_palette("husl")

# %%
N = 50

data1 = np.random.randn(N)
data2 = np.random.rand(N)

# %%
df = pd.DataFrame({'Gaussian': data1, 'Uniform': data2}, columns=['Gaussian', 'Uniform'])

# %%
sns.boxplot(df,orient='v')
# Out:
# <Axes: >

# %%
sns.displot(df)
